# %%
# =========================
# function1 테스트
# =========================
def test_function1():
    results = [
        function1(10, 60, 70, 50),
        function1(60, 70, 80),
        function1(10, 20, 30)
    ]
    expected = [130, 210, 0]

    for i in range(len(results)):
        if results[i] != expected[i]:
            print(f"❌ function1 Test {i+1} 실패")
            print("결과:", results[i], "정답:", expected[i])
            return
    print("✅ function1 통과")


# =========================
# function2 테스트
# =========================
def test_function2():
    results = [
        function2("A123b45c"),
        function2("123Hello123"),
        function2("2025Happy")
    ]
    expected = ["abc", "hello", "happy"]

    for i in range(len(results)):
        if results[i] != expected[i]:
            print(f"❌ function2 Test {i+1} 실패")
            print("결과:", results[i], "정답:", expected[i])
            return
    print("✅ function2 통과")


# =========================
# function3 테스트
# =========================
def test_function3():
    results = [
        function3(a=5, bb=10, c=3),
        function3(aa=5, bb=10),
        function3(a=1, b=2)
    ]
    expected = [10, 15, 0]

    for i in range(len(results)):
        if results[i] != expected[i]:
            print(f"❌ function3 Test {i+1} 실패")
            print("결과:", results[i], "정답:", expected[i])
            return
    print("✅ function3 통과")


# =========================
# function4 테스트
# =========================
def test_function4():
    results = [
        function4([1, 2, 3, 4]),
        function4([-2, 2, 4]),
        function4([1, 3, 5])
    ]
    expected = [6, 6, 0]

    for i in range(len(results)):
        if results[i] != expected[i]:
            print(f"❌ function4 Test {i+1} 실패")
            print("결과:", results[i], "정답:", expected[i])
            return
    print("✅ function4 통과")


# =========================
# function5 테스트
# =========================
def test_function5():
    results = [
        function5(1, 2, 3, 4, a=5, b=10),
        function5(2, 4, 6, aa=3, ab=5),
        function5(1, 3, 5)
    ]
    expected = [11, 20, 0]

    for i in range(len(results)):
        if results[i] != expected[i]:
            print(f"❌ function5 Test {i+1} 실패")
            print("결과:", results[i], "정답:", expected[i])
            return
    print("✅ function5 통과")

# %% [markdown]
# 문제 1
# 함수 이름: function1
#
# 설명
#
# 이 함수는 개수가 정해지지 않은 위치 인자를 입력받는다
# 모든 인자는 정수이다
#
# 조건
#
# 60점 이상인 값들만 골라 합을 반환하시오
# 조건을 만족하는 값이 없으면 0을 반환하시오
#
# 예시
#
# function1(10, 60, 70, 50) -> 130
# function1(60, 70, 80) -> 210
# function1(10, 20, 30) -> 0

# %%
def function1(___):
    # TODO


grader.check(1, function1(10, 60, 70, 50))

# %% [markdown]
# 문제 2
# 함수 이름: function2
#
# 설명
#
# 이 함수는 하나의 위치 인자를 입력받는다
# 문자열은 숫자와 알파벳으로 구성되어 있다
#
# 조건
#
# 숫자는 모두 제거하시오
# 알파벳만 남기고 모두 소문자로 변환하여 반환하시오
#
# 예시
#
# function2("A123b45c") -> "abc"
# function2("123Hello123") -> "hello"
# function2("2025Happy") -> "happy"

# %%
def function2(___):
    # TODO


grader.check(2, function2("A123b45c"))

# %% [markdown]
# 문제 3
# 함수 이름: function3
#
# 설명
#
# 이 함수는 개수가 정해지지 않은 키워드 인자를 입력받는다
# 모든 값은 정수이다
#
# 조건
#
# key의 길이가 2 이상인 경우만 선택한다
# 해당 value들을 모두 더하여 반환하시오
# 조건을 만족하는 값이 없으면 0을 반환하시오
#
# 예시
#
# function3(a=5, bb=10, c=3) -> 10
# function3(aa=5, bb=10) -> 15
# function3(a=1, b=2) -> 0

# %%
def function3(___):
    # TODO


grader.check(3, function3(a=5, bb=10, c=3))

# %% [markdown]
# 문제 4
# 함수 이름: function4
#
# 설명
#
# 이 함수는 하나의 위치 인자를 입력받는다
# 정수로 이루어진 리스트이다
#
# 조건
#
# 짝수만 선택하여 더하시오
# 음수는 모두 제외하시오
# 조건을 만족하는 값이 없으면 0을 반환하시오
#
# 예시
#
# function4([1, 2, 3, 4]) -> 6
# function4([-2, 2, 4]) -> 6
# function4([1, 3, 5]) -> 0

# %%
def function4(___):
    # TODO


grader.check(4, function4([1, 2, 3, 4]))

# %% [markdown]
# 문제 5
# 함수 이름: function5
#
# 설명
#
# 이 함수는 개수가 정해지지 않은 위치 인자와 키워드 인자를 입력받는다
# 모든 값은 정수이다
#
# 조건
#
# 위치 인자(args)에서는 짝수만 골라 더한다
# 키워드 인자(kwargs)에서는 key가 'a'로 시작하는 값만 더한다
# 두 결과를 합하여 반환하시오
#
# 예시
#
# function5(1, 2, 3, 4, a=5, b=10) -> 11
# function5(2, 4, 6, aa=3, ab=5) -> 20
# function5(1, 3, 5) -> 0

# %%
def function5(___):
    # TODO


grader.check(5, function5(1, 2, 3, 4, a=5, b=10))   # 11
grader.check(5, function5(2, 4, 6, aa=3, ab=5))     # 20
grader.check(5, function5(1, 3, 5))                 # 0
